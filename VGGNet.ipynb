# %%
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler
from math import floor
import os
import torchvision.models

# %%
import torchvision.models as models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
vggnet = models.vgg19(pretrained=True)
# Out:
# C:\Users\hdape\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\hdape\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
train_path = 'DataSet/VGG2_Gen2_NewAug_V3/Training'
pokemonlist = os.listdir('DataSet/VGG2_Gen2_NewAug_V3/Training')
data_transforms = transforms.Compose([
                    transforms.Resize((224,224)),
                    transforms.ToTensor()])
train_datasets = torchvision.datasets.ImageFolder(root = train_path, transform = data_transforms)

hyperparameters = [1,1]

train_loader = torch.utils.data.DataLoader(train_datasets, batch_size=hyperparameters[0], num_workers=hyperparameters[1], shuffle=True, collate_fn=None, pin_memory=False)
def features_to_folder(loader, path):
    n = 0
    for img, label in loader:
      features = vggnet.features(img)

      features_tensor = torch.from_numpy(features.detach().numpy())
      x = torch.tensor(label)
      print(features_tensor.shape)
      print('working on ' + str(pokemonList[x.item()]))
      # show the overall progress
      print('working on ' + str(n) + ' out of ' + str(len(train_datasets)))

      q = x.item()
      folder_name = path + '/' + str(pokemonList[q])
      if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
      torch.save(features_tensor.squeeze(0), folder_name + '/' + str(n) + '.tensor')
      n += 1

features_to_folder(train_loader, train_path)

def test(loader, path):
  for img, label in loader:
      features = vggnet.features(img)
      features_tensor = torch.from_numpy(features.detach().numpy())
      x = torch.tensor(label)
      if features_tensor.shape[1] != 512:
        print(features_tensor.shape, pokemonList[x.item()])
#test(train_loader, train_path)
# Out:
# C:\Users\hdape\AppData\Local\Temp\ipykernel_31620\1077587920.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(label)
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 0 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blastoise
# working on 1 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Entei
# working on 2 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charmander
# working on 3 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skiploom
# working on 4 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowpoke
# working on 5 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 6 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Donphan
# working on 7 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 8 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 9 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 10 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bulbasaur
# working on 11 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charmeleon
# working on 12 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gligar
# working on 13 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyrogue
# working on 14 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bayleef
# working on 15 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rattata
# working on 16 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 17 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Igglybuff
# working on 18 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 19 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skarmory
# working on 20 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shellder
# working on 21 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gloom
# working on 22 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arbok
# working on 23 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyrogue
# working on 24 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Larvitar
# working on 25 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowking
# working on 26 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mew
# working on 27 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seel
# working on 28 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weepinbell
# working on 29 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowking
# working on 30 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Noctowl
# working on 31 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jynx
# working on 32 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhydon
# working on 33 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machamp
# working on 34 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arbok
# working on 35 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ninetales
# working on 36 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weepinbell
# working on 37 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meganium
# working on 38 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Onix
# working on 39 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndour
# working on 40 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoothoot
# working on 41 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeot
# working on 42 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoppip
# working on 43 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ninetales
# working on 44 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aipom
# working on 45 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zapdos
# working on 46 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seadra
# working on 47 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gloom
# working on 48 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 49 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Marowak
# working on 50 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 51 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shellder
# working on 52 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magby
# working on 53 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 54 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Metapod
# working on 55 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zubat
# working on 56 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Metapod
# working on 57 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venomoth
# working on 58 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rapidash
# working on 59 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rattata
# working on 60 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowking
# working on 61 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gligar
# working on 62 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Murkrow
# working on 63 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 64 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kakuna
# working on 65 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 66 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 67 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 68 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ampharos
# working on 69 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Oddish
# working on 70 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pupitar
# working on 71 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingler
# working on 72 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Marill
# working on 73 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Starmie
# working on 74 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonlee
# working on 75 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togetic
# working on 76 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 77 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowbro
# working on 78 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Paras
# working on 79 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 80 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magikarp
# working on 81 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Crobat
# working on 82 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raticate
# working on 83 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Umbreon
# working on 84 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 85 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seel
# working on 86 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skarmory
# working on 87 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Primeape
# working on 88 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ledyba
# working on 89 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Steelix
# working on 90 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omastar
# working on 91 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Qwilfish
# working on 92 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magmar
# working on 93 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ivysaur
# working on 94 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shuckle
# working on 95 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zubat
# working on 96 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bayleef
# working on 97 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kadabra
# working on 98 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Natu
# working on 99 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Exeggcute
# working on 100 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 101 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blastoise
# working on 102 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pikachu
# working on 103 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowpoke
# working on 104 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 105 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vaporeon
# working on 106 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon2
# working on 107 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chikorita
# working on 108 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golbat
# working on 109 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jigglypuff
# working on 110 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 111 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 112 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Piloswine
# working on 113 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Metapod
# working on 114 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scizor
# working on 115 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 116 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magikarp
# working on 117 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 118 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arbok
# working on 119 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Goldeen
# working on 120 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndoom
# working on 121 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Parasect
# working on 122 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lickitung
# working on 123 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 124 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Drowzee
# working on 125 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 126 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefairy
# working on 127 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flaaffy
# working on 128 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hypno
# working on 129 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meowth
# working on 130 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venonat
# working on 131 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togepi
# working on 132 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ursaring
# working on 133 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwag
# working on 134 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ledyba
# working on 135 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 136 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunkern
# working on 137 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tangela
# working on 138 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dewgong
# working on 139 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorino
# working on 140 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togepi
# working on 141 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorina
# working on 142 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Donphan
# working on 143 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Natu
# working on 144 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Oddish
# working on 145 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dugtrio
# working on 146 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Crobat
# working on 147 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machamp
# working on 148 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Abra
# working on 149 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 150 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Crobat
# working on 151 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Delibird
# working on 152 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skarmory
# working on 153 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Primeape
# working on 154 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 155 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Electrode
# working on 156 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dunsparce
# working on 157 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magnemite
# working on 158 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Eevee
# working on 159 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magmar
# working on 160 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cloyster
# working on 161 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ekans
# working on 162 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 163 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pichu
# working on 164 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ivysaur
# working on 165 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raichu
# working on 166 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Paras
# working on 167 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Donphan
# working on 168 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charizard
# working on 169 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Diglett
# working on 170 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Donphan
# working on 171 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Goldeen
# working on 172 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Granbull
# working on 173 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Exeggutor
# working on 174 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venomoth
# working on 175 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 176 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Haunter
# working on 177 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 178 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandshrew
# working on 179 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoppip
# working on 180 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon
# working on 181 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 182 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Koffing
# working on 183 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Horsea
# working on 184 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cyndaquil
# working on 185 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machop
# working on 186 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 187 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wartortle
# working on 188 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 189 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kadabra
# working on 190 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 191 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandshrew
# working on 192 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Igglybuff
# working on 193 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mr. Mime
# working on 194 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Marill
# working on 195 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tentacruel
# working on 196 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zubat
# working on 197 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 198 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mantine
# working on 199 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pineco
# working on 200 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 201 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pichu
# working on 202 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Totodile
# working on 203 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Quilava
# working on 204 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhyhorn
# working on 205 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omanyte
# working on 206 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 207 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 208 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togepi
# working on 209 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rapidash
# working on 210 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charizard
# working on 211 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Butterfree
# working on 212 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefairy
# working on 213 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Primeape
# working on 214 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omastar
# working on 215 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 216 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 217 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 218 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raticate
# working on 219 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mankey
# working on 220 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Quagsire
# working on 221 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smoochum
# working on 222 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weepinbell
# working on 223 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingler
# working on 224 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Espeon
# working on 225 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Starmie
# working on 226 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smoochum
# working on 227 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidoking
# working on 228 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gengar
# working on 229 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyranitar
# working on 230 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Celebi
# working on 231 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tentacool
# working on 232 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonlee
# working on 233 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Horsea
# working on 234 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 235 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kakuna
# working on 236 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyranitar
# working on 237 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magby
# working on 238 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonchan
# working on 239 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunflora
# working on 240 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonite
# working on 241 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 242 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandslash
# working on 243 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tentacruel
# working on 244 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonite
# working on 245 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dugtrio
# working on 246 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndour
# working on 247 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 248 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhyhorn
# working on 249 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Diglett
# working on 250 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mr. Mime
# working on 251 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zapdos
# working on 252 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mankey
# working on 253 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seaking
# working on 254 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venusaur
# working on 255 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scizor
# working on 256 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonchan
# working on 257 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 258 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cubone
# working on 259 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Goldeen
# working on 260 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 261 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 262 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Igglybuff
# working on 263 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ursaring
# working on 264 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 265 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 266 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jolteon
# working on 267 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ursaring
# working on 268 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Unown
# working on 269 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeotto
# working on 270 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 271 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gengar
# working on 272 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charmeleon
# working on 273 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 274 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Qwilfish
# working on 275 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Yanma
# working on 276 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tauros
# working on 277 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seaking
# working on 278 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flaaffy
# working on 279 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 280 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cyndaquil
# working on 281 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mareep
# working on 282 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 283 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Paras
# working on 284 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Piloswine
# working on 285 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aipom
# working on 286 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Elekid
# working on 287 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunflora
# working on 288 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mewtwo
# working on 289 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machamp
# working on 290 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 291 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 292 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Onix
# working on 293 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Celebi
# working on 294 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Squirtle
# working on 295 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aerodactyl
# working on 296 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon2
# working on 297 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingdra
# working on 298 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Caterpie
# working on 299 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Haunter
# working on 300 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandshrew
# working on 301 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venonat
# working on 302 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 303 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seel
# working on 304 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Primeape
# working on 305 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwag
# working on 306 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ho-oh
# working on 307 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Igglybuff
# working on 308 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 309 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunkern
# working on 310 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Entei
# working on 311 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 312 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ditto
# working on 313 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 314 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 315 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 316 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 317 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jolteon
# working on 318 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 319 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 320 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoothoot
# working on 321 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Oddish
# working on 322 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Delibird
# working on 323 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Granbull
# working on 324 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gligar
# working on 325 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ivysaur
# working on 326 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vulpix
# working on 327 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seadra
# working on 328 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Celebi
# working on 329 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lanturn
# working on 330 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 331 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 332 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwrath
# working on 333 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 334 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aerodactyl
# working on 335 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Politoed
# working on 336 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Donphan
# working on 337 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omanyte
# working on 338 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gengar
# working on 339 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mewtwo
# working on 340 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 341 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omanyte
# working on 342 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndoom
# working on 343 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowking
# working on 344 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Articuno
# working on 345 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhyhorn
# working on 346 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhydon
# working on 347 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ekans
# working on 348 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 349 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 350 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 351 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyrogue
# working on 352 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 353 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venusaur
# working on 354 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Delibird
# working on 355 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vulpix
# working on 356 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 357 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonair
# working on 358 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zubat
# working on 359 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Azumarill
# working on 360 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Furret
# working on 361 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Paras
# working on 362 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Natu
# working on 363 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Abra
# working on 364 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Steelix
# working on 365 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magnemite
# working on 366 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 367 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 368 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cleffa
# working on 369 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vileplume
# working on 370 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weedle
# working on 371 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Piloswine
# working on 372 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 373 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Delibird
# working on 374 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 375 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tangela
# working on 376 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoppip
# working on 377 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingdra
# working on 378 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dunsparce
# working on 379 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lugia
# working on 380 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smoochum
# working on 381 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omastar
# working on 382 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 383 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 384 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scizor
# working on 385 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Corsola
# working on 386 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 387 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 388 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skiploom
# working on 389 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Elekid
# working on 390 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mareep
# working on 391 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 392 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Staryu
# working on 393 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 394 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndoom
# working on 395 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 396 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorina
# working on 397 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sudowoodo
# working on 398 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 399 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Psyduck
# working on 400 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 401 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shellder
# working on 402 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pupitar
# working on 403 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meowth
# working on 404 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 405 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golduck
# working on 406 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raichu
# working on 407 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shellder
# working on 408 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wartortle
# working on 409 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gastly
# working on 410 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 411 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Eevee
# working on 412 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mewtwo
# working on 413 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 414 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pikachu
# working on 415 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndour
# working on 416 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Heracross
# working on 417 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 418 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 419 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 420 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowking
# working on 421 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Muk
# working on 422 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sneasel
# working on 423 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 424 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flareon
# working on 425 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandshrew
# working on 426 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mewtwo
# working on 427 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefairy
# working on 428 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Quagsire
# working on 429 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgey
# working on 430 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ursaring
# working on 431 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scyther
# working on 432 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Teddiursa
# working on 433 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slugma
# working on 434 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kakuna
# working on 435 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Entei
# working on 436 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 437 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgey
# working on 438 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 439 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magneton
# working on 440 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Geodude
# working on 441 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Beedrill
# working on 442 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ho-oh
# working on 443 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 444 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunkern
# working on 445 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwrath
# working on 446 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeotto
# working on 447 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 448 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Yanma
# working on 449 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonair
# working on 450 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ninetales
# working on 451 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shuckle
# working on 452 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 453 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 454 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 455 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tentacool
# working on 456 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ninetales
# working on 457 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ho-oh
# working on 458 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 459 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jolteon
# working on 460 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 461 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 462 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Crobat
# working on 463 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 464 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dratini
# working on 465 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 466 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cyndaquil
# working on 467 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 468 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meowth
# working on 469 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeot
# working on 470 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Politoed
# working on 471 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kadabra
# working on 472 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smeargle
# working on 473 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ho-oh
# working on 474 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pikachu
# working on 475 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefairy
# working on 476 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Furret
# working on 477 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 478 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 479 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Zubat
# working on 480 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 481 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tauros
# working on 482 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Oddish
# working on 483 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raikou
# working on 484 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Xatu
# working on 485 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lanturn
# working on 486 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dewgong
# working on 487 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cloyster
# working on 488 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Houndour
# working on 489 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Persian
# working on 490 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonair
# working on 491 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Steelix
# working on 492 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Qwilfish
# working on 493 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonair
# working on 494 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwrath
# working on 495 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 496 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tauros
# working on 497 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 498 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowpoke
# working on 499 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Omanyte
# working on 500 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seaking
# working on 501 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ponyta
# working on 502 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 503 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chansey
# working on 504 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jynx
# working on 505 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mantine
# working on 506 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kadabra
# working on 507 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Goldeen
# working on 508 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 509 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 510 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mankey
# working on 511 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lickitung
# working on 512 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hoppip
# working on 513 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ho-oh
# working on 514 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Teddiursa
# working on 515 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 516 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Xatu
# working on 517 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dewgong
# working on 518 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flaaffy
# working on 519 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 520 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flareon
# working on 521 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dratini
# working on 522 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meowth
# working on 523 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jolteon
# working on 524 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jigglypuff
# working on 525 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingdra
# working on 526 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 527 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golduck
# working on 528 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Spinarak
# working on 529 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Unown
# working on 530 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 531 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 532 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunkern
# working on 533 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gengar
# working on 534 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arbok
# working on 535 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gloom
# working on 536 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lapras
# working on 537 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Abra
# working on 538 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ivysaur
# working on 539 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Psyduck
# working on 540 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 541 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 542 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 543 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Noctowl
# working on 544 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Koffing
# working on 545 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sneasel
# working on 546 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Exeggutor
# working on 547 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Psyduck
# working on 548 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 549 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raichu
# working on 550 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Shellder
# working on 551 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lapras
# working on 552 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gastly
# working on 553 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mr. Mime
# working on 554 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dewgong
# working on 555 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meganium
# working on 556 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Corsola
# working on 557 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Persian
# working on 558 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Spinarak
# working on 559 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vulpix
# working on 560 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aipom
# working on 561 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smoochum
# working on 562 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 563 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dugtrio
# working on 564 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machamp
# working on 565 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weepinbell
# working on 566 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 567 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Elekid
# working on 568 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandslash
# working on 569 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charizard
# working on 570 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sudowoodo
# working on 571 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golduck
# working on 572 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lapras
# working on 573 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magikarp
# working on 574 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 575 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magneton
# working on 576 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chansey
# working on 577 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seaking
# working on 578 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wigglytuff
# working on 579 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jumpluff
# working on 580 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 581 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raichu
# working on 582 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Electabuzz
# working on 583 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyranitar
# working on 584 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flaaffy
# working on 585 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Larvitar
# working on 586 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venomoth
# working on 587 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 588 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Murkrow
# working on 589 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowpoke
# working on 590 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Haunter
# working on 591 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Corsola
# working on 592 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwag
# working on 593 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ivysaur
# working on 594 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tangela
# working on 595 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Snubbull
# working on 596 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mareep
# working on 597 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meowth
# working on 598 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 599 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golem
# working on 600 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 601 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wigglytuff
# working on 602 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ledian
# working on 603 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mareep
# working on 604 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 605 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Starmie
# working on 606 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 607 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tauros
# working on 608 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyranitar
# working on 609 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scizor
# working on 610 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 611 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slugma
# working on 612 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magmar
# working on 613 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raikou
# working on 614 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 615 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pupitar
# working on 616 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon
# working on 617 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arbok
# working on 618 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Qwilfish
# working on 619 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 620 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togepi
# working on 621 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gligar
# working on 622 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raticate
# working on 623 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Eevee
# working on 624 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Noctowl
# working on 625 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Remoraid
# working on 626 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Skarmory
# working on 627 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sudowoodo
# working on 628 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 629 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weezing
# working on 630 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cleffa
# working on 631 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 632 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 633 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 634 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sunflora
# working on 635 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Geodude
# working on 636 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charmeleon
# working on 637 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kabuto
# working on 638 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyrogue
# working on 639 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Slowbro
# working on 640 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 641 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonchan
# working on 642 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Elekid
# ...
# working on Qwilfish
# working on 19710 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19711 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon2
# working on 19712 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 19713 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Elekid
# working on 19714 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kakuna
# working on 19715 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Stantler
# working on 19716 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gastly
# working on 19717 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Miltank
# working on 19718 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Diglett
# working on 19719 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wobbuffet
# working on 19720 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Diglett
# working on 19721 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Muk
# working on 19722 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jigglypuff
# working on 19723 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chikorita
# working on 19724 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kadabra
# working on 19725 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Suicune
# working on 19726 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 19727 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellsprout
# working on 19728 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scyther
# working on 19729 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 19730 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pikachu
# working on 19731 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 19732 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Persian
# working on 19733 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Metapod
# working on 19734 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pichu
# working on 19735 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blastoise
# working on 19736 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 19737 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ledian
# working on 19738 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Spinarak
# working on 19739 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Typhlosion
# working on 19740 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Raikou
# working on 19741 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 19742 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 19743 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgey
# working on 19744 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmontop
# working on 19745 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 19746 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dewgong
# working on 19747 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dugtrio
# working on 19748 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cleffa
# working on 19749 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cubone
# working on 19750 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Haunter
# working on 19751 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Spearow
# working on 19752 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Geodude
# working on 19753 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rapidash
# working on 19754 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 19755 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magcargo
# working on 19756 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Snorlax
# working on 19757 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhydon
# working on 19758 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ninetales
# working on 19759 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Remoraid
# working on 19760 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Croconaw
# working on 19761 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgey
# working on 19762 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pineco
# working on 19763 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ampharos
# working on 19764 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Abra
# working on 19765 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sneasel
# working on 19766 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon
# working on 19767 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venomoth
# working on 19768 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Furret
# working on 19769 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Flaaffy
# working on 19770 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Mankey
# working on 19771 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cyndaquil
# working on 19772 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Smeargle
# working on 19773 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 19774 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefairy
# working on 19775 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magneton
# working on 19776 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jolteon
# working on 19777 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Onix
# working on 19778 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 19779 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jigglypuff
# working on 19780 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ponyta
# working on 19781 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ponyta
# working on 19782 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Snubbull
# working on 19783 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 19784 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pupitar
# working on 19785 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machop
# working on 19786 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorino
# working on 19787 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Entei
# working on 19788 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Togetic
# working on 19789 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 19790 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonite
# working on 19791 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Feraligatr
# working on 19792 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 19793 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Venusaur
# working on 19794 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Steelix
# working on 19795 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seaking
# working on 19796 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vileplume
# working on 19797 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lapras
# working on 19798 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Arcanine
# working on 19799 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hitmonlee
# working on 19800 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Spinarak
# working on 19801 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Wigglytuff
# working on 19802 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Murkrow
# working on 19803 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyrogue
# working on 19804 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Krabby
# working on 19805 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Geodude
# working on 19806 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Hypno
# working on 19807 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pineco
# working on 19808 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeot
# working on 19809 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 19810 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19811 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidoqueen
# working on 19812 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 19813 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Weedle
# working on 19814 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kabuto
# working on 19815 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Snorlax
# working on 19816 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gligar
# working on 19817 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aerodactyl
# working on 19818 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Farfetch'd
# working on 19819 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meganium
# working on 19820 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Celebi
# working on 19821 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Steelix
# working on 19822 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cleffa
# working on 19823 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magmar
# working on 19824 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 19825 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeotto
# working on 19826 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 19827 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cloyster
# working on 19828 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Grimer
# working on 19829 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 19830 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Marill
# working on 19831 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Politoed
# working on 19832 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 19833 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Miltank
# working on 19834 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jynx
# working on 19835 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Poliwhirl
# working on 19836 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorina
# working on 19837 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Bellossom
# working on 19838 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Golbat
# working on 19839 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Clefable
# working on 19840 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Victreebel
# working on 19841 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dragonair
# working on 19842 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Aipom
# working on 19843 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Marill
# working on 19844 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon2
# working on 19845 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chansey
# working on 19846 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Machamp
# working on 19847 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19848 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Magcargo
# working on 19849 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Doduo
# working on 19850 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Drowzee
# working on 19851 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandslash
# working on 19852 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pinsir
# working on 19853 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 19854 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Phanpy
# working on 19855 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seel
# working on 19856 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 19857 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 19858 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lanturn
# working on 19859 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 19860 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Piloswine
# working on 19861 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pineco
# working on 19862 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 19863 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Seel
# working on 19864 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chikorita
# working on 19865 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gastly
# working on 19866 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Chinchou
# working on 19867 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Lapras
# working on 19868 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Girafarig
# working on 19869 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19870 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kakuna
# working on 19871 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Murkrow
# working on 19872 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Gyarados
# working on 19873 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 19874 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Rhyhorn
# working on 19875 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Tyranitar
# working on 19876 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pineco
# working on 19877 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingler
# working on 19878 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sandshrew
# working on 19879 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Meganium
# working on 19880 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19881 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidorino
# working on 19882 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Growlith
# working on 19883 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Larvitar
# working on 19884 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Murkrow
# working on 19885 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Muk
# working on 19886 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Misdreavus
# working on 19887 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Parasect
# working on 19888 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Blissey
# working on 19889 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Octillery
# working on 19890 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ledyba
# working on 19891 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scyther
# working on 19892 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Forretress
# working on 19893 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Exeggcute
# working on 19894 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dunsparce
# working on 19895 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Dodrio
# working on 19896 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Fearow
# working on 19897 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charizard
# working on 19898 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Nidoking
# working on 19899 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19900 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Kingdra
# working on 19901 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Graveler
# working on 19902 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Noctowl
# working on 19903 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Haunter
# working on 19904 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Ariados
# working on 19905 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Charmeleon
# working on 19906 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Scyther
# working on 19907 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Oddish
# working on 19908 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Cleffa
# working on 19909 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Vaporeon
# working on 19910 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Whooper
# working on 19911 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Porygon
# working on 19912 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Jynx
# working on 19913 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Espeon
# working on 19914 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Metapod
# working on 19915 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Muk
# working on 19916 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Sentret
# working on 19917 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Beedrill
# working on 19918 out of 19920
# torch.Size([1, 512, 7, 7])
# working on Pidgeot
# working on 19919 out of 19920

# %%
#Base VGGNet
class Pokemon_Classifier_VGGNet(nn.Module):
    def __init__(self, name = "Pokemon_Classifier_VGGNet"):
          self.name = "Pokemon_Classifier_VGGNet"
          super(Pokemon_Classifier_VGGNet, self).__init__()
          self.conv1 = nn.Conv2d(256, 50, 2) #in_channels, out_chanels, kernel_size
          self.conv2 = nn.Conv2d(50, 10, 2) #in_channels, out_chanels, kernel_size
          self.fc1 = nn.Linear(10*4*4, 300)
          self.fc2 = nn.Linear(300, len(pokemonList))

    def forward(self, x):
          x = F.relu(self.conv1(x))
          x = F.relu(self.conv2(x))
          x = x.view(-1, 10*4*4)
          print("Here",x.shape())
          x = F.relu(self.fc1(x))
          x = self.fc2(x)
          return x

# %%
def plotting(epochs, loss_chart, train_acc, val_acc):
    plt.title("Training Loss Curve")
    plt.plot(epochs, loss_chart, label="Train")
    plt.plot(epochs, val_acc, label="Validation")
    plt.xlabel("Iterations")
    plt.ylabel("Loss")
    plt.show()

    plt.title("Training Accuracy Curve")
    plt.plot(epochs, train_acc, label="Train")
    plt.xlabel("Iterations")
    plt.ylabel("Training Accuracy")
    plt.legend(loc='best')
    plt.show()

# %%
use_cuda = True
def get_accuracy(model, test_loader):
    data = test_loader

    correct = 0
    total = 0
    for imgs, labels in data:
        #############################################
        #To Enable GPU Usage
        if use_cuda and torch.cuda.is_available():
          imgs = imgs.cuda()
          labels = labels.cuda()
        #############################################
        output = model(imgs)
        #select index with maximum prediction score
        pred = output.max(1, keepdim=True)[1]
        correct += pred.eq(labels.view_as(pred)).sum().item()
        total += imgs.shape[0]
    return correct / total

# %%
use_cuda = True
def train(model, train_dataset, val_dataset, batch_size=128, learning_rate=0.001, num_epochs=20):

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, 
                                              num_workers=0, shuffle=True, drop_last = True)
    val_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, 
                                              num_workers=1, shuffle=True, drop_last = True)
    train_acc = np.zeros(num_epochs)
    val_acc = np.zeros(num_epochs)
    loss_chart = np.zeros(num_epochs)
    epochs = []


    for imgs, labels in iter(train_loader):
      print(imgs.shape)
      print(pokemonList[labels[0]])
      print(imgs)
      break
      
    # training

    n = 0
    for epoch in range(num_epochs):
        total_train_loss = 0.0
        total_train_err = 0.0
        total_images = 0
        print(train_loader.dataset)
        for imgs, labels in iter(train_loader):
            print("h")
            if use_cuda == True:
              imgs, labels = imgs.cuda(), labels.cuda()

            out = model(imgs)             # forward pass
            print("After out")
            loss = criterion(out, labels) # compute the total loss
            print("After Loss")
            loss.backward()               # backward pass (compute parameter updates)
            print("After Back")
            optimizer.step()              # make the updates for each parameter
            optimizer.zero_grad()         # a clean up step for PyTorch
        n += 1
        epochs.append(n)          
        
        # track accuracy
        train_acc[epoch] = get_accuracy(model, train_loader)
        val_acc[epoch] = get_accuracy(model, val_loader)
        loss_chart[epoch] = float(loss)/batch_size
        model_path = f"model_{model.name}_bs{batch_size}_lr{learning_rate}_epoch{epoch}"
        torch.save(model.state_dict(), model_path)


        print((f"Epoch {epoch+1}: Train accuracy = {train_acc[epoch]}"))

    epochs = np.arange(1, num_epochs + 1)

    plotting(epochs,loss_chart,train_acc, val_acc)

    print("Final Training Accuracy: {}".format(train_acc[-1]))
    print("Final Validation Accuracy: {}".format(val_acc[-1]))
    
    return train_acc, epochs

train_path = "DataSet/VGG2_Gen2_NewAug_V3/Training"
data_transforms = transforms.Compose([
                    transforms.Resize((224,224)),
                    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])
train_dataset_new = torchvision.datasets.DatasetFolder(train_path, loader=torch.load, extensions=('.tensor'), transform=data_transforms)
val_path = "DataSet/VGG2_Gen2_NewAug_V3/Validation"
model = Pokemon_Classifier_VGGNet()
if use_cuda and torch.cuda.is_available():
  model.cuda()
  print('CUDA is available!  Training on GPU ...')
else:
  print('CUDA is not available.  Training on CPU ...')


train(model, train_dataset_new, val_path, batch_size = 1, learning_rate = 0.001, num_epochs=10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 69
#      65 train_path = "DataSet/VGG2_Gen2_NewAug_V3/Training"
#      66 data_transforms = transforms.Compose([
#      67                     transforms.Resize((224,224)),
#      68                     transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))])
# ---> 69 train_dataset_new = torchvision.datasets.DatasetFolder(train_path, loader=torch.load, extensions=('.tensor'), transform=data_transforms)
#      70 val_path = "DataSet/VGG2_Gen2_NewAug_V3/Validation"
#      71 model = Pokemon_Classifier_VGGNet()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\datasets\folder.py:145, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file)
#     143 super().__init__(root, transform=transform, target_transform=target_transform)
#     144 classes, class_to_idx = self.find_classes(self.root)
# --> 145 samples = self.make_dataset(self.root, class_to_idx, extensions, is_valid_file)
#     147 self.loader = loader
#     148 self.extensions = extensions
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\datasets\folder.py:189, in DatasetFolder.make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     184 if class_to_idx is None:
#     185     # prevent potential bug since make_dataset() would use the class_to_idx logic of the
#     186     # find_classes() function, instead of using that of the find_classes() method, which
#     187     # is potentially overridden and thus could have a different logic.
#     188     raise ValueError("The class_to_idx parameter cannot be None.")
# --> 189 return make_dataset(directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\torchvision\datasets\folder.py:102, in make_dataset(directory, class_to_idx, extensions, is_valid_file)
#     100     if extensions is not None:
#     101         msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 102     raise FileNotFoundError(msg)
#     104 return instances
#
# FileNotFoundError: Found no valid file for the classes Farfetch_d. Supported extensions are: .tensor
